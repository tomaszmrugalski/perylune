# %%
from poliastro.plotting.porkchop import porkchop
from poliastro.bodies import Earth, Mars
from poliastro.util import time_range
launch_span = time_range("2020-04-01", end="2020-09-15")
arrival_span = time_range("2020-12-01", end="2021-07-30")
dv_launch, dev_dpt, c3dpt, c3arr, tof = porkchop(Earth, Mars, launch_span, arrival_span, tfl=False, vhp=False)
